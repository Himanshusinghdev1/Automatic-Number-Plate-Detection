# %%
import torch

# Load your trained model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/Users/himanshu/Downloads/DataScience/DA/Automatic-Number-Plate-Detection/models/best.pt')

# Test on an image
results = model('/Users/himanshu/Downloads/DataScience/DA/Automatic-Number-Plate-Detection/artifacts/data_ingestion/TEST/TEST.jpeg')
results.show()  # Display results
results.save('results/')  # Save annotated images
# Out:
# Using cache found in /Users/himanshu/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-8-21 Python-3.8.20 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=901x729>
# Saved 1 image to runs/detect/exp
